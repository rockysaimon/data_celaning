# %% [markdown]
# <a href="https://colab.research.google.com/github/rockysaimon/data_celaning/blob/main/mineria_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data cleaning Minería de datos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Dataset usado de kaggle
# link: https://www.kaggle.com/datasets/iabhishekofficial/mobile-price-classification?select=test.csv

# %% [markdown]
# > **Primero importamos os para movernos entre los archivos y encontrar la dirección de nuestros archivos**

# %%
import os

# %%
os.chdir("drive/MyDrive/Colab Notebooks/mineriaDatos")
os.listdir()
# Out:
# ['test.csv',
#  'train.csv',
#  'train.gsheet',
#  'traindf.csv',
#  'main.csv',
#  'mineria_de_datos.ipynb']

# %% [markdown]
# > **Aquí tenemos los datasets, por lo que importamos Pandas y mostramos el contenido**

# %%
import pandas as pd

# %% [markdown]
# > *imprimir dataset completo*

# %%
pd.set_option('display.max_columns', None) # línea para que no resuma las columnas
data=pd.read_csv("main.csv")
data.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim    fc  four_g  int_memory  \
# 0          842.0     0          2.2         0   1.0       0           7
# 1         1021.0     1          0.5         1   0.0       1          53
# 2          563.0     1          0.5         1   2.0       1          41
# 3          615.0     1          2.5         0   0.0       0          10
# 4         1821.0     1          1.2         0  13.0       1          44
# 5         1859.0     0          0.5         1   3.0       0          22
# 6         1821.0     0          1.7         0   4.0       1          10
# 7         1954.0     0          0.5         1   0.0       0          24
# 8         1445.0     1          0.5         0   0.0       0          53
# 9          509.0     1          0.6         1   2.0       1           9
#
#    m_dep  mobile_wt  n_cores  pc  px_height  px_width     ram  sc_h  sc_w  \
# 0    0.6        188      2.0   2         20       756  2549.0     9     7
# ...

# %%
data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    1997.000000  2000.0000  2000.000000  2000.000000  1999.000000
# mean     1307.485228     0.4950     1.522850     0.509500     4.294647
# std      2877.415457     0.5001     0.815969     0.500035     4.330876
# min    -31110.000000     0.0000     0.500000     0.000000     0.000000
# 25%       852.000000     0.0000     0.700000     0.000000     1.000000
# 50%      1230.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1617.000000     1.0000     2.200000     1.000000     7.000000
# max    111131.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  2000.000000  2000.000000  1998.000000  2000.000000  1997.000000
# mean      0.522000    32.051500     0.501802   140.255000     4.537807
# std       0.499641    18.136436     0.288482    35.381335     2.375391
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  1997 non-null   float64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             1999 non-null   float64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          1998 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        1997 non-null   float64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            1996 non-null   float64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      1998 non-null   float64
# ...

# %% [markdown]
# # **ÍNDICE**
#
#
# > 1. Cambiar nombre columnas
# 2. Especificar los rangos de precio
# 4. Valores nulos
# 5. Outliers
# 6. Cambio de tipo de dato

# %% [markdown]
# # Cambiar nombres de columnas

# %%
nombres_nuevos={
    "battery_power":"battery_mAh",
    "blue":"bluethoot",
    "clock_speed":"clock_speed",
    "dual_sim":"dual_sim",
    "fc":"front_camera_mp",
    "four_g":"4G",
    "int_memory":"memory_GB",
    "m_dep":"mobile_depth_cm",
    "mobile_wt":"mobile_weight_gr",
    "n_cores":"processor_cores",
    "pc":"primary_camera_mp",
    "px_height":"pixel_resolution_h",
    "px_width":"pixel_resolution_w",
    "ram":"ram_MB",
    "sc_h":"screen_height_cm",
    "sc_w":"screen_width_cm",
    "talk_time":"battery_time",
    "three_g":"3G",
    "touch_screen":"touch_screen",
    "wifi":"wifi",
    "price_range":"price_range"
}

df=data.rename(columns=nombres_nuevos)
df.head(10)
# Out:
#    battery_mAh  bluethoot  clock_speed  dual_sim  front_camera_mp  4G  \
# 0        842.0          0          2.2         0              1.0   0
# 1       1021.0          1          0.5         1              0.0   1
# 2        563.0          1          0.5         1              2.0   1
# 3        615.0          1          2.5         0              0.0   0
# 4       1821.0          1          1.2         0             13.0   1
# 5       1859.0          0          0.5         1              3.0   0
# 6       1821.0          0          1.7         0              4.0   1
# 7       1954.0          0          0.5         1              0.0   0
# 8       1445.0          1          0.5         0              0.0   0
# 9        509.0          1          0.6         1              2.0   1
#
#    memory_GB  mobile_depth_cm  mobile_weight_gr  processor_cores  \
# 0          7              0.6               188              2.0
# ...

# %% [markdown]
# # Especificar rango de precios

# %%
rango_precio = {
    0: 'bajo',
    1: 'medio',
    2: 'alto',
    3: 'muy alto'
}

df["price_range"] = df["price_range"].replace(rango_precio)
df.head(10)
# Out:
#    battery_mAh  bluethoot  clock_speed  dual_sim  front_camera_mp  4G  \
# 0        842.0          0          2.2         0              1.0   0
# 1       1021.0          1          0.5         1              0.0   1
# 2        563.0          1          0.5         1              2.0   1
# 3        615.0          1          2.5         0              0.0   0
# 4       1821.0          1          1.2         0             13.0   1
# 5       1859.0          0          0.5         1              3.0   0
# 6       1821.0          0          1.7         0              4.0   1
# 7       1954.0          0          0.5         1              0.0   0
# 8       1445.0          1          0.5         0              0.0   0
# 9        509.0          1          0.6         1              2.0   1
#
#    memory_GB  mobile_depth_cm  mobile_weight_gr  processor_cores  \
# 0          7              0.6               188              2.0
# ...

# %% [markdown]
# **Comprobar si hay datos duplicados**

# %%
duplicados = df[df.duplicated()]
print("Filas duplicadas:")
duplicados
# Out:
# Filas duplicadas:
#      battery_mAh  bluethoot  clock_speed  dual_sim  front_camera_mp  4G  \
# 47        1723.0          1          1.1         1              1.0   0
# 157       1485.0          0          1.0         0              2.0   1
# 310        601.0          1          1.4         0              4.0   1
# 371        879.0          0          1.5         1              0.0   1
# 482       1067.0          1          2.4         1              3.0   1
#
#      memory_GB  mobile_depth_cm  mobile_weight_gr  processor_cores  \
# 47          42              1.0               164              8.0
# 157         32              0.7                84              2.0
# 310          4              0.1               154              4.0
# 371         21              0.8               187              4.0
# 482         40              0.6               122              8.0
#
#      primary_camera_mp  pixel_resolution_h  pixel_resolution_w  ram_MB  \
# ...

# %% [markdown]
# **eliminar datos duplicados**

# %%
df = df.drop_duplicates()
print("DataFrame sin duplicados:")
df.info()
# Out:
# DataFrame sin duplicados:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1995 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   battery_mAh         1992 non-null   float64
#  1   bluethoot           1995 non-null   int64
#  2   clock_speed         1995 non-null   float64
#  3   dual_sim            1995 non-null   int64
#  4   front_camera_mp     1994 non-null   float64
#  5   4G                  1995 non-null   int64
#  6   memory_GB           1995 non-null   int64
#  7   mobile_depth_cm     1993 non-null   float64
#  8   mobile_weight_gr    1995 non-null   int64
#  9   processor_cores     1992 non-null   float64
#  10  primary_camera_mp   1995 non-null   int64
#  11  pixel_resolution_h  1995 non-null   int64
#  12  pixel_resolution_w  1995 non-null   int64
#  13  ram_MB              1991 non-null   float64
#  14  screen_height_cm    1995 non-null   int64
# ...

# %% [markdown]
# **comprobar**

# %%
duplicados = df[df.duplicated()]
print("Filas duplicadas:")
duplicados
# Out:
# Filas duplicadas:
# Empty DataFrame
# Columns: [battery_mAh, bluethoot, clock_speed, dual_sim, front_camera_mp, 4G, memory_GB, mobile_depth_cm, mobile_weight_gr, processor_cores, primary_camera_mp, pixel_resolution_h, pixel_resolution_w, ram_MB, screen_height_cm, screen_width_cm, battery_time, 3G, touch_screen, wifi, price_range]
# Index: []

# %% [markdown]
# # valores nulos

# %%
conteo_nulos_por_columna = df.isnull().sum()
print("Conteo de valores nulos por columna:")
conteo_nulos_por_columna
# Out:
# Conteo de valores nulos por columna:
# battery_mAh           3
# bluethoot             0
# clock_speed           0
# dual_sim              0
# front_camera_mp       1
# 4G                    0
# memory_GB             0
# mobile_depth_cm       2
# mobile_weight_gr      0
# processor_cores       3
# primary_camera_mp     0
# pixel_resolution_h    0
# pixel_resolution_w    0
# ram_MB                4
# screen_height_cm      0
# screen_width_cm       0
# battery_time          2
# 3G                    0
# touch_screen          0
# wifi                  0
# price_range           0
# dtype: int64

# %% [markdown]
# **eliminar filas con nulos**

# %%
df = df.dropna()
print("DataFrame sin filas nulas:")
df.info()
# Out:
# DataFrame sin filas nulas:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1980 entries, 0 to 1998
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   battery_mAh         1980 non-null   float64
#  1   bluethoot           1980 non-null   int64
#  2   clock_speed         1980 non-null   float64
#  3   dual_sim            1980 non-null   int64
#  4   front_camera_mp     1980 non-null   float64
#  5   4G                  1980 non-null   int64
#  6   memory_GB           1980 non-null   int64
#  7   mobile_depth_cm     1980 non-null   float64
#  8   mobile_weight_gr    1980 non-null   int64
#  9   processor_cores     1980 non-null   float64
#  10  primary_camera_mp   1980 non-null   int64
#  11  pixel_resolution_h  1980 non-null   int64
#  12  pixel_resolution_w  1980 non-null   int64
#  13  ram_MB              1980 non-null   float64
#  14  screen_height_cm    1980 non-null   int64
# ...

# %% [markdown]
# **outliers**

# %%
df.head()
# Out:
#    battery_mAh  bluethoot  clock_speed  dual_sim  front_camera_mp  4G  \
# 0        842.0          0          2.2         0              1.0   0
# 1       1021.0          1          0.5         1              0.0   1
# 2        563.0          1          0.5         1              2.0   1
# 3        615.0          1          2.5         0              0.0   0
# 4       1821.0          1          1.2         0             13.0   1
#
#    memory_GB  mobile_depth_cm  mobile_weight_gr  processor_cores  \
# 0          7              0.6               188              2.0
# 1         53              0.7               136              3.0
# 2         41              0.9               145              5.0
# 3         10              0.8               131              6.0
# 4         44              0.6               141              2.0
#
#    primary_camera_mp  pixel_resolution_h  pixel_resolution_w  ram_MB  \
# 0                  2                  20                 756  2549.0
# ...

# %% [markdown]
# # outliers

# %% [markdown]
# ## Outliers columna battery_mAh

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.boxplot(df['battery_mAh'], vert=False)  # Utiliza vert=False para hacer el boxplot horizontal
plt.title('Boxplot de la columna específica')
plt.xlabel('Valores')
plt.ylabel('Columna específica')
plt.grid(True)
plt.show()

# %%
# Identificar outliers utilizando el método del rango intercuartílico (IQR)
Q1 = df["battery_mAh"].quantile(0.25)
Q3 = df["battery_mAh"].quantile(0.75)
IQR = Q3 - Q1

# Calcular límites del rango intercuartílico (IQR) con un factor personalizado y un límite inferior más alto que 0
factor_escala = 1.5  # Puedes ajustar este valor según tus necesidades
limite_inferior = Q1 - factor_escala * IQR  #  Establece el límite inferior como máximo entre 0 y el cálculo del IQR
limite_superior = Q3 + factor_escala * IQR
print(limite_inferior,limite_superior)

# Eliminar filas con outliers en las columnas seleccionadas
df = df[(df["battery_mAh"] >= limite_inferior) & (df["battery_mAh"] <= limite_superior)]

# Mostrar el DataFrame resultante sin outliers
df.info()
# Out:
# -295.5 2764.5
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1973 entries, 0 to 1998
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   battery_mAh         1973 non-null   float64
#  1   bluethoot           1973 non-null   int64
#  2   clock_speed         1973 non-null   float64
#  3   dual_sim            1973 non-null   int64
#  4   front_camera_mp     1973 non-null   float64
#  5   4G                  1973 non-null   int64
#  6   memory_GB           1973 non-null   int64
#  7   mobile_depth_cm     1973 non-null   float64
#  8   mobile_weight_gr    1973 non-null   int64
#  9   processor_cores     1973 non-null   float64
#  10  primary_camera_mp   1973 non-null   int64
#  11  pixel_resolution_h  1973 non-null   int64
#  12  pixel_resolution_w  1973 non-null   int64
#  13  ram_MB              1973 non-null   float64
#  14  screen_height_cm    1973 non-null   int64
# ...

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['battery_mAh'], vert=False)  # Utiliza vert=False para hacer el boxplot horizontal
plt.title('Boxplot de la columna específica')
plt.xlabel('Valores')
plt.ylabel('Columna específica')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Outliers columna ram_MB

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['ram_MB'], vert=False)  # Utiliza vert=False para hacer el boxplot horizontal
plt.title('Boxplot de la columna específica')
plt.xlabel('Valores')
plt.ylabel('Columna específica')
plt.grid(True)
plt.show()

# %%
# Identificar outliers utilizando el método del rango intercuartílico (IQR)
Q1 = df["ram_MB"].quantile(0.25)
Q3 = df["ram_MB"].quantile(0.75)
IQR = Q3 - Q1

# Calcular límites del rango intercuartílico (IQR) con un factor personalizado y un límite inferior más alto que 0
factor_escala = 1.5  # Puedes ajustar este valor según tus necesidades
limite_inferior = Q1 - factor_escala * IQR  #  Establece el límite inferior como máximo entre 0 y el cálculo del IQR
limite_superior = Q3 + factor_escala * IQR
print(limite_inferior,limite_superior)

# Eliminar filas con outliers en las columnas seleccionadas
df = df[(df["ram_MB"] >= limite_inferior) & (df["ram_MB"] <= limite_superior)]
# Out:
# -1583.0 5865.0

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['ram_MB'], vert=False)  # Utiliza vert=False para hacer el boxplot horizontal
plt.title('Boxplot de la columna específica')
plt.xlabel('Valores')
plt.ylabel('Columna específica')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Outliers columna processor_cores

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['processor_cores'], vert=False)  # Utiliza vert=False para hacer el boxplot horizontal
plt.title('Boxplot de la columna específica')
plt.xlabel('Valores')
plt.ylabel('Columna específica')
plt.grid(True)
plt.show()

# %%
# Identificar outliers utilizando el método del rango intercuartílico (IQR)
Q1 = df["processor_cores"].quantile(0.25)
Q3 = df["processor_cores"].quantile(0.75)
IQR = Q3 - Q1

# Calcular límites del rango intercuartílico (IQR) con un factor personalizado y un límite inferior más alto que 0
factor_escala = 1.5  # Puedes ajustar este valor según tus necesidades
limite_inferior = Q1 - factor_escala * IQR  #  Establece el límite inferior como máximo entre 0 y el cálculo del IQR
limite_superior = Q3 + factor_escala * IQR
print(limite_inferior,limite_superior)

# Eliminar filas con outliers en las columnas seleccionadas
df = df[(df["processor_cores"] >= limite_inferior) & (df["processor_cores"] <= limite_superior)]
# Out:
# -3.0 13.0

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['processor_cores'], vert=False)  # Utiliza vert=False para hacer el boxplot horizontal
plt.title('Boxplot de la columna específica')
plt.xlabel('Valores')
plt.ylabel('Columna específica')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Outliers columna battery_time

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['battery_time'], vert=False)  # Utiliza vert=False para hacer el boxplot horizontal
plt.title('Boxplot de la columna específica')
plt.xlabel('Valores')
plt.ylabel('Columna específica')
plt.grid(True)
plt.show()

# %%
# Identificar outliers utilizando el método del rango intercuartílico (IQR)
Q1 = df["battery_time"].quantile(0.25)
Q3 = df["battery_time"].quantile(0.75)
IQR = Q3 - Q1

# Calcular límites del rango intercuartílico (IQR) con un factor personalizado y un límite inferior más alto que 0
factor_escala = 1.5  # Puedes ajustar este valor según tus necesidades
limite_inferior = Q1 - factor_escala * IQR  #  Establece el límite inferior como máximo entre 0 y el cálculo del IQR
limite_superior = Q3 + factor_escala * IQR
print(limite_inferior,limite_superior)

# Eliminar filas con outliers en las columnas seleccionadas
df = df[(df["battery_time"] >= limite_inferior) & (df["battery_time"] <= limite_superior)]
# Out:
# -9.0 31.0

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['battery_time'], vert=False)  # Utiliza vert=False para hacer el boxplot horizontal
plt.title('Boxplot de la columna específica')
plt.xlabel('Valores')
plt.ylabel('Columna específica')
plt.grid(True)
plt.show()

# %% [markdown]
# # Cambiar tipo de datos de columnas

# %%
df.head()
# Out:
#    battery_mAh  bluethoot  clock_speed  dual_sim  front_camera_mp  4G  \
# 0        842.0          0          2.2         0              1.0   0
# 1       1021.0          1          0.5         1              0.0   1
# 2        563.0          1          0.5         1              2.0   1
# 3        615.0          1          2.5         0              0.0   0
# 4       1821.0          1          1.2         0             13.0   1
#
#    memory_GB  mobile_depth_cm  mobile_weight_gr  processor_cores  \
# 0          7              0.6               188              2.0
# 1         53              0.7               136              3.0
# 2         41              0.9               145              5.0
# 3         10              0.8               131              6.0
# 4         44              0.6               141              2.0
#
#    primary_camera_mp  pixel_resolution_h  pixel_resolution_w  ram_MB  \
# 0                  2                  20                 756  2549.0
# ...

# %% [markdown]
# podemos ver que las columnas battery_mAh, ram_Mb y battery_time tienen un tipo de datos no acorde que es float, cambiémoslo a int

# %%
columnas_int=["battery_mAh","ram_MB","battery_time"]
df[columnas_int] = df[columnas_int].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1959 entries, 0 to 1998
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   battery_mAh         1959 non-null   int64
#  1   bluethoot           1959 non-null   int64
#  2   clock_speed         1959 non-null   float64
#  3   dual_sim            1959 non-null   int64
#  4   front_camera_mp     1959 non-null   float64
#  5   4G                  1959 non-null   int64
#  6   memory_GB           1959 non-null   int64
#  7   mobile_depth_cm     1959 non-null   float64
#  8   mobile_weight_gr    1959 non-null   int64
#  9   processor_cores     1959 non-null   float64
#  10  primary_camera_mp   1959 non-null   int64
#  11  pixel_resolution_h  1959 non-null   int64
#  12  pixel_resolution_w  1959 non-null   int64
#  13  ram_MB              1959 non-null   int64
#  14  screen_height_cm    1959 non-null   int64
# ...

# %% [markdown]
# # MODELO DE PREDICCIÓN DE 5 CAPAS

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# modelo de entrenamiento

# %%
le = LabelEncoder()
df['price_range_encoded'] = le.fit_transform(df['price_range'])

# Separar los datos en características (X) y etiquetas (y)
X = df.drop(['price_range', 'price_range_encoded'], axis=1)
y = df['price_range_encoded']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Crear el modelo con 20 capas
model = tf.keras.Sequential()
model.add(tf.keras.layers.Input(shape=X_train.shape[1]))

# Añadir 20 capas ocultas con activación ReLU
for _ in range(25):
    model.add(tf.keras.layers.Dense(64, activation='relu'))

# Añadir capa de salida con activación softmax para clasificación multiclase
model.add(tf.keras.layers.Dense(4, activation='softmax'))
model.add(tf.keras.layers.Dense(4, activation='softmax'))

# Compilar el modelo
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Resumen del modelo
model.summary()

# Entrenar el modelo
model.fit(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_70 (Dense)            (None, 64)                1344
#
#  dense_71 (Dense)            (None, 64)                4160
#
#  dense_72 (Dense)            (None, 64)                4160
#
#  dense_73 (Dense)            (None, 64)                4160
#
#  dense_74 (Dense)            (None, 64)                4160
#
#  dense_75 (Dense)            (None, 64)                4160
#
#  dense_76 (Dense)            (None, 64)                4160
#
#  dense_77 (Dense)            (None, 64)                4160
#
#  dense_78 (Dense)            (None, 64)                4160
#
#  dense_79 (Dense)            (None, 64)                4160
#
#  dense_80 (Dense)            (None, 64)                4160
#
#  dense_81 (Dense)            (None, 64)                4160
#
#  dense_82 (Dense)            (None, 64)                4160
#
# ...

# %%
categorias_string_inverso = {
    0: 'bajo',
    1: 'medio',
    2: 'alto',
    3: 'muy alto'
}
# Obtener las predicciones del modelo en el conjunto de datos de prueba
predicciones = model.predict(X_test)
# Convertir las probabilidades predichas a las clases predichas (índice de la clase con la probabilidad más alta)
predicciones_clases = np.argmax(predicciones, axis=1)

# Decodificar las clases predichas y los resultados esperados de números a categorías de string utilizando el diccionario categorias_string_inverso
predicciones_string = [categorias_string_inverso[indice] for indice in predicciones_clases]
resultados_esperados = [categorias_string_inverso[indice] for indice in y_test]

# Imprimir cinco ejemplos de predicciones y resultados esperados
for i in range(5):
    print("Ejemplo", i+1)
    print("Características:")
    print(X_test.iloc[i])  # Acceder a la fila del conjunto de datos de prueba
    print("Predicción:", predicciones_string[i])
    print("Resultado esperado:", resultados_esperados[i])
    print()
# Out:
# 19/19 [==============================] - 0s 2ms/step
# Ejemplo 1
# Características:
# battery_mAh            673.0
# bluethoot                1.0
# clock_speed              2.2
# dual_sim                 1.0
# front_camera_mp          2.0
# 4G                       0.0
# memory_GB                3.0
# mobile_depth_cm          0.4
# mobile_weight_gr        84.0
# processor_cores          2.0
# primary_camera_mp        9.0
# pixel_resolution_h    1109.0
# pixel_resolution_w    1247.0
# ram_MB                2719.0
# screen_height_cm        19.0
# screen_width_cm          2.0
# battery_time             9.0
# 3G                       1.0
# touch_screen             1.0
# wifi                     1.0
# Name: 1174, dtype: float64
# Predicción: bajo
# Resultado esperado: bajo
#
# Ejemplo 2
# Características:
# battery_mAh           1137.0
# bluethoot                0.0
# clock_speed              2.2
# dual_sim                 0.0
# front_camera_mp          6.0
# 4G                       1.0
# ...

# %%
dataf=df
dataf
# Out:
#       battery_mAh  bluethoot  clock_speed  dual_sim  front_camera_mp  4G  \
# 0             842          0          2.2         0              1.0   0
# 1            1021          1          0.5         1              0.0   1
# 2             563          1          0.5         1              2.0   1
# 3             615          1          2.5         0              0.0   0
# 4            1821          1          1.2         0             13.0   1
# ...           ...        ...          ...       ...              ...  ..
# 1994          858          0          2.2         0              1.0   0
# 1995          794          1          0.5         1              0.0   1
# 1996         1965          1          2.6         1              0.0   0
# 1997         1911          0          0.9         1              1.0   1
# 1998         1512          0          0.9         0              4.0   1
#
#       memory_GB  mobile_depth_cm  mobile_weight_gr  processor_cores  \
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['price_range'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='battery_mAh', y='price_range', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-90-47d7a7c5043e>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df, x='battery_mAh', y='price_range', inner='box', palette='Dark2')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('price_range').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
